# %%
from googleapiclient.discovery import build
from dateutil import parser
import pandas as pd
from IPython.display import JSON

# Data viz packages
import seaborn as sns
import matplotlib.pyplot as plt
import matplotlib.ticker as ticker

# %%
api_key="AIzaSyCqBt7QcetXo-wQvBJKDKLQ2rgTnYxqNbk"
channel_id="UCnjU1FHmao9YNfPzE039YTw"

# %%
api_service_name = "youtube"
api_version = "v3"

# %%
 youtube =build(api_service_name, api_version, developerKey=api_key)

# %%
def get_channel_stats(youtube, channel_id):
    
    request = youtube.channels().list(
        part="snippet,contentDetails,statistics",
        id=channel_id
    )
    response = request.execute()

    # loop through items
    for item in response['items']:
        data = {'channelName': item['snippet']['title'],
                'subscribers': item['statistics']['subscriberCount'],
                'views': item['statistics']['viewCount'],
                'totalVideos': item['statistics']['videoCount'],
                'playlistId': item['contentDetails']['relatedPlaylists']['uploads']
        }
        
        
    return data

# %%
channel_stats =get_channel_stats(youtube, channel_id)

# %%
channel_data=pd.DataFrame(channel_stats,index=[0])

# %%
channel_data
# Out:
#     channelName subscribers      views totalVideos                playlistId
# 0  Irfan's view     3430000  865638364        1789  UUnjU1FHmao9YNfPzE039YTw

# %%
playlist_id='UUnjU1FHmao9YNfPzE039YTw'
def get_video_ids(youtube, playlist_id):
    
    video_ids = []
    
    request = youtube.playlistItems().list(
        part="snippet,contentDetails",
        playlistId=playlist_id,
        maxResults = 50
    )
    response = request.execute()
    
    for item in response['items']:
        video_ids.append(item['contentDetails']['videoId'])
        
    next_page_token = response.get('nextPageToken')
    while next_page_token is not None:
        request = youtube.playlistItems().list(
                    part='contentDetails',
                    playlistId = playlist_id,
                    maxResults = 50,
                    pageToken = next_page_token)
        response = request.execute()

        for item in response['items']:
            video_ids.append(item['contentDetails']['videoId'])

        next_page_token = response.get('nextPageToken')
        
    return video_ids

# %%
video_ids=get_video_ids(youtube, playlist_id)

# %%
len(video_ids)
# Out:
# 1793

# %%
def get_video_details(youtube, video_ids):

    all_video_info = []
    
    for i in range(0, len(video_ids), 50):
        request = youtube.videos().list(
            part="snippet,contentDetails,statistics",
            id=','.join(video_ids[i:i+50])
        )
        response = request.execute() 

        for video in response['items']:
            stats_to_keep = {'snippet': ['channelTitle', 'title', 'description', 'tags', 'publishedAt'],
                             'statistics': ['viewCount', 'likeCount', 'favouriteCount', 'commentCount'],
                             'contentDetails': ['duration', 'definition', 'caption']
                            }
            video_info = {}
            video_info['video_id'] = video['id']

            for k in stats_to_keep.keys():
                for v in stats_to_keep[k]:
                    try:
                        video_info[v] = video[k][v]
                    except:
                        video_info[v] = None

            all_video_info.append(video_info)
    
    return pd.DataFrame(all_video_info)

# %%
video_df=get_video_details(youtube, video_ids)

# %%
video_df
# Out:
#          video_id  channelTitle  \
# 0     qzn5plzoFy4  Irfan's view
# 1     8JfFa_tVNnw  Irfan's view
# 2     G_O17o4AvLY  Irfan's view
# 3     My5SPvaNBPY  Irfan's view
# 4     RswH8Qvavys  Irfan's view
# ...           ...           ...
# 1788  OzvmKdF5XWI  Irfan's view
# 1789  bT7pKT802WI  Irfan's view
# 1790  4L_YNSjpUfM  Irfan's view
# 1791  zItcM8BZv6g  Irfan's view
# 1792  8REFx4FbKQs  Irfan's view
#
#                                                   title  \
# 0     Birthday Celebration with Nepoleon Sir's Famil...
# 1     Driving to Nepoleon's Party in Truck For 400 K...
# 2     Hooters Bar in America | Chicken Wings 🔥 - Irf...
# 3     Disappointed 😡Gordon Ramsay's Fish & Chips - I...
# 4     MrBeast Burger For First Time 🔥 🇺🇲 - Irfan's View
# ...                                                 ...
# 1788                     How to fish in Bay of Bengal!!
# 1789   Mutton samosa - Crescent and Betel leaf | Vlog 3
# 1790          Biryani, Tiffin and Tea with bun | VLOG 2
# 1791  First vlog - Chennai, KFC, Bournvita, Hide & s...
# 1792                              Kavalai vendam Review
#
#                                             description  \
# 0     #irfansview #nepoleon #usa \n\nIn this video, ...
# 1     #irfansview #nepoleon #usa\n\nIn this video, i...
# 2     #irfansview #hooters #america \n\nIn this vide...
# 3     #irfansview #gordonramsay #usa \n\nIn this vid...
# 4     #irfansview #mrbeast #america\n\nIn this video...
# ...                                                 ...
# 1788  Fishing in Bay of Bengal via CHENNAI, kasimedu...
# 1789  Crescent hotel food and betel leaf and betel n...
# 1790  From Puliyodarai to Biryani - South indian tif...
# 1791  This is my first vlog - Will be posting vlog e...
# 1792  Kavalai Vendam is an Indian Tamil romantic com...
#
#                                                    tags           publishedAt  \
# 0     [irfan's view, food review, irfanview, tamil f...  2022-12-28T09:30:12Z
# 1     [irfan's view, food review, irfanview, tamil f...  2022-12-27T09:47:32Z
# 2     [irfan's view, food review, irfanview, tamil f...  2022-12-26T09:30:56Z
# 3     [irfan's view, food review, irfanview, tamil f...  2022-12-25T09:30:07Z
# 4     [irfan's view, food review, irfanview, tamil f...  2022-12-24T09:36:34Z
# ...                                                 ...                   ...
# 1788  [Chennai, How to fish, Bay of bengal, Vardah, ...  2016-12-19T12:15:45Z
# 1789                                   [Chennai, Hotel]  2016-12-13T19:41:17Z
# 1790  [Biryani, Chennai, Chennai Vlog, Irfan's vlog,...  2016-12-05T01:56:33Z
# 1791                 [Chennai, Foods, Vlog, Food vlogs]  2016-11-28T02:11:07Z
# 1792  [kavalai vendam review, kavalai vendam, Tamil ...  2016-11-25T00:45:45Z
#
#      viewCount likeCount favouriteCount commentCount  duration definition  \
# 0       692201     32307           None         1957  PT17M45S         hd
# 1       580405     19020           None          678   PT9M38S         hd
# 2       453079     15917           None          752   PT11M5S         hd
# 3       391078     12986           None          675  PT11M14S         hd
# 4       497822     20678           None          596   PT8M51S         hd
# ...        ...       ...            ...          ...       ...        ...
# 1788     40253      1194           None           80  PT14M27S         hd
# 1789     47003      1116           None           59  PT14M23S         hd
# 1790     91702      2327           None          126  PT14M51S         hd
# 1791    267809     12690           None         1199  PT19M19S         hd
# 1792    154342      7217           None          651   PT5M34S         hd
#
#      caption
# 0      false
# 1       true
# 2      false
# 3       true
# 4       true
# ...      ...
# 1788   false
# 1789   false
# 1790   false
# 1791   false
# 1792   false
#
# [1793 rows x 13 columns]

# %% [markdown]
# Data pre-processing

# %%
#checking null value
video_df.isnull().sum()
# Out:
# video_id             0
# channelTitle         0
# title                0
# description          0
# tags                37
# publishedAt          0
# viewCount            0
# likeCount            0
# favouriteCount    1793
# commentCount         4
# duration             0
# definition           0
# caption              0
# dtype: int64

# %%
#checking datatypes
video_df.dtypes
# Out:
# video_id          object
# channelTitle      object
# title             object
# description       object
# tags              object
# publishedAt       object
# viewCount         object
# likeCount         object
# favouriteCount    object
# commentCount      object
# duration          object
# definition        object
# caption           object
# dtype: object

# %%
# Convert count columns to numeric
numeric_cols = ['viewCount', 'likeCount', 'favouriteCount', 'commentCount']
video_df[numeric_cols] = video_df[numeric_cols].apply(pd.to_numeric, errors = 'coerce', axis = 1)

# %%
# Publish day in the week
video_df['publishedAt'] = video_df['publishedAt'].apply(lambda x: parser.parse(x)) 
video_df['pushblishDayName'] = video_df['publishedAt'].apply(lambda x: x.strftime("%A"))

# %%
# convert duration to seconds
import isodate
video_df['durationSecs'] = video_df['duration'].apply(lambda x: isodate.parse_duration(x))
video_df['durationSecs'] = video_df['durationSecs'].astype('timedelta64[s]')

# %%
video_df[['durationSecs', 'duration']]
# Out:
#       durationSecs  duration
# 0           1065.0  PT17M45S
# 1            578.0   PT9M38S
# 2            665.0   PT11M5S
# 3            674.0  PT11M14S
# 4            531.0   PT8M51S
# ...            ...       ...
# 1788         867.0  PT14M27S
# 1789         863.0  PT14M23S
# 1790         891.0  PT14M51S
# 1791        1159.0  PT19M19S
# 1792         334.0   PT5M34S
#
# [1793 rows x 2 columns]

# %%
# Add tag count
video_df['tagCount'] = video_df['tags'].apply(lambda x: 0 if x is None else len(x))

# %%
video_df
# Out:
#          video_id  channelTitle  \
# 0     qzn5plzoFy4  Irfan's view
# 1     8JfFa_tVNnw  Irfan's view
# 2     G_O17o4AvLY  Irfan's view
# 3     My5SPvaNBPY  Irfan's view
# 4     RswH8Qvavys  Irfan's view
# ...           ...           ...
# 1788  OzvmKdF5XWI  Irfan's view
# 1789  bT7pKT802WI  Irfan's view
# 1790  4L_YNSjpUfM  Irfan's view
# 1791  zItcM8BZv6g  Irfan's view
# 1792  8REFx4FbKQs  Irfan's view
#
#                                                   title  \
# 0     Birthday Celebration with Nepoleon Sir's Famil...
# 1     Driving to Nepoleon's Party in Truck For 400 K...
# 2     Hooters Bar in America | Chicken Wings 🔥 - Irf...
# 3     Disappointed 😡Gordon Ramsay's Fish & Chips - I...
# 4     MrBeast Burger For First Time 🔥 🇺🇲 - Irfan's View
# ...                                                 ...
# 1788                     How to fish in Bay of Bengal!!
# 1789   Mutton samosa - Crescent and Betel leaf | Vlog 3
# 1790          Biryani, Tiffin and Tea with bun | VLOG 2
# 1791  First vlog - Chennai, KFC, Bournvita, Hide & s...
# 1792                              Kavalai vendam Review
#
#                                             description  \
# 0     #irfansview #nepoleon #usa \n\nIn this video, ...
# 1     #irfansview #nepoleon #usa\n\nIn this video, i...
# 2     #irfansview #hooters #america \n\nIn this vide...
# 3     #irfansview #gordonramsay #usa \n\nIn this vid...
# 4     #irfansview #mrbeast #america\n\nIn this video...
# ...                                                 ...
# 1788  Fishing in Bay of Bengal via CHENNAI, kasimedu...
# 1789  Crescent hotel food and betel leaf and betel n...
# 1790  From Puliyodarai to Biryani - South indian tif...
# 1791  This is my first vlog - Will be posting vlog e...
# 1792  Kavalai Vendam is an Indian Tamil romantic com...
#
#                                                    tags  \
# 0     [irfan's view, food review, irfanview, tamil f...
# 1     [irfan's view, food review, irfanview, tamil f...
# 2     [irfan's view, food review, irfanview, tamil f...
# 3     [irfan's view, food review, irfanview, tamil f...
# 4     [irfan's view, food review, irfanview, tamil f...
# ...                                                 ...
# 1788  [Chennai, How to fish, Bay of bengal, Vardah, ...
# 1789                                   [Chennai, Hotel]
# 1790  [Biryani, Chennai, Chennai Vlog, Irfan's vlog,...
# 1791                 [Chennai, Foods, Vlog, Food vlogs]
# 1792  [kavalai vendam review, kavalai vendam, Tamil ...
#
#                    publishedAt  viewCount  likeCount  favouriteCount  \
# 0    2022-12-28 09:30:12+00:00   692201.0    32307.0             NaN
# 1    2022-12-27 09:47:32+00:00   580405.0    19020.0             NaN
# 2    2022-12-26 09:30:56+00:00   453079.0    15917.0             NaN
# 3    2022-12-25 09:30:07+00:00   391078.0    12986.0             NaN
# 4    2022-12-24 09:36:34+00:00   497822.0    20678.0             NaN
# ...                        ...        ...        ...             ...
# 1788 2016-12-19 12:15:45+00:00    40253.0     1194.0             NaN
# 1789 2016-12-13 19:41:17+00:00    47003.0     1116.0             NaN
# 1790 2016-12-05 01:56:33+00:00    91702.0     2327.0             NaN
# 1791 2016-11-28 02:11:07+00:00   267809.0    12690.0             NaN
# 1792 2016-11-25 00:45:45+00:00   154342.0     7217.0             NaN
#
#       commentCount  duration definition caption pushblishDayName  \
# 0           1957.0  PT17M45S         hd   false        Wednesday
# 1            678.0   PT9M38S         hd    true          Tuesday
# 2            752.0   PT11M5S         hd   false           Monday
# 3            675.0  PT11M14S         hd    true           Sunday
# 4            596.0   PT8M51S         hd    true         Saturday
# ...            ...       ...        ...     ...              ...
# 1788          80.0  PT14M27S         hd   false           Monday
# 1789          59.0  PT14M23S         hd   false          Tuesday
# 1790         126.0  PT14M51S         hd   false           Monday
# 1791        1199.0  PT19M19S         hd   false           Monday
# 1792         651.0   PT5M34S         hd   false           Friday
#
#       durationSecs  tagCount
# 0           1065.0        32
# 1            578.0        32
# 2            665.0        32
# 3            674.0        34
# 4            531.0        35
# ...            ...       ...
# 1788         867.0         7
# 1789         863.0         2
# 1790         891.0         7
# 1791        1159.0         4
# 1792         334.0         5
#
# [1793 rows x 16 columns]

# %% [markdown]
# EDA
# Best performing videos

# %%
ax = sns.barplot(x = 'title', y = 'viewCount', data = video_df.sort_values('viewCount', ascending=False)[0:9])
plot = ax.set_xticklabels(ax.get_xticklabels(), rotation=90)
ax.yaxis.set_major_formatter(ticker.FuncFormatter(lambda x, pos:'{:,.0f}'.format(x/1000) + 'K'))
# Out:
# C:\Users\kaleeshwaran m\anaconda3\lib\site-packages\IPython\core\pylabtools.py:151: UserWarning: Glyph 129321 (\N{GRINNING FACE WITH STAR EYES}) missing from current font.
#   fig.canvas.print_figure(bytes_io, **kw)
# C:\Users\kaleeshwaran m\anaconda3\lib\site-packages\IPython\core\pylabtools.py:151: UserWarning: Glyph 128293 (\N{FIRE}) missing from current font.
#   fig.canvas.print_figure(bytes_io, **kw)
# C:\Users\kaleeshwaran m\anaconda3\lib\site-packages\IPython\core\pylabtools.py:151: UserWarning: Glyph 2997 (\N{TAMIL LETTER VA}) missing from current font.
#   fig.canvas.print_figure(bytes_io, **kw)
# C:\Users\kaleeshwaran m\anaconda3\lib\site-packages\IPython\core\pylabtools.py:151: UserWarning: Matplotlib currently does not support Tamil natively.
#   fig.canvas.print_figure(bytes_io, **kw)
# C:\Users\kaleeshwaran m\anaconda3\lib\site-packages\IPython\core\pylabtools.py:151: UserWarning: Glyph 3008 (\N{TAMIL VOWEL SIGN II}) missing from current font.
#   fig.canvas.print_figure(bytes_io, **kw)
# C:\Users\kaleeshwaran m\anaconda3\lib\site-packages\IPython\core\pylabtools.py:151: UserWarning: Glyph 2975 (\N{TAMIL LETTER TTA}) missing from current font.
#   fig.canvas.print_figure(bytes_io, **kw)
# C:\Users\kaleeshwaran m\anaconda3\lib\site-packages\IPython\core\pylabtools.py:151: UserWarning: Glyph 3021 (\N{TAMIL SIGN VIRAMA}) missing from current font.
#   fig.canvas.print_figure(bytes_io, **kw)
# C:\Users\kaleeshwaran m\anaconda3\lib\site-packages\IPython\core\pylabtools.py:151: UserWarning: Glyph 3009 (\N{TAMIL VOWEL SIGN U}) missing from current font.
#   fig.canvas.print_figure(bytes_io, **kw)
# C:\Users\kaleeshwaran m\anaconda3\lib\site-packages\IPython\core\pylabtools.py:151: UserWarning: Glyph 2990 (\N{TAMIL LETTER MA}) missing from current font.
#   fig.canvas.print_figure(bytes_io, **kw)
# C:\Users\kaleeshwaran m\anaconda3\lib\site-packages\IPython\core\pylabtools.py:151: UserWarning: Glyph 2985 (\N{TAMIL LETTER NNNA}) missing from current font.
#   fig.canvas.print_figure(bytes_io, **kw)
# C:\Users\kaleeshwaran m\anaconda3\lib\site-packages\IPython\core\pylabtools.py:151: UserWarning: Glyph 2970 (\N{TAMIL LETTER CA}) missing from current font.
#   fig.canvas.print_figure(bytes_io, **kw)
# C:\Users\kaleeshwaran m\anaconda3\lib\site-packages\IPython\core\pylabtools.py:151: UserWarning: Glyph 3006 (\N{TAMIL VOWEL SIGN AA}) missing from current font.
#   fig.canvas.print_figure(bytes_io, **kw)
# C:\Users\kaleeshwaran m\anaconda3\lib\site-packages\IPython\core\pylabtools.py:151: UserWarning: Glyph 2986 (\N{TAMIL LETTER PA}) missing from current font.
#   fig.canvas.print_figure(bytes_io, **kw)
# C:\Users\kaleeshwaran m\anaconda3\lib\site-packages\IPython\core\pylabtools.py:151: UserWarning: Glyph 3010 (\N{TAMIL VOWEL SIGN UU}) missing from current font.
#   fig.canvas.print_figure(bytes_io, **kw)
# C:\Users\kaleeshwaran m\anaconda3\lib\site-packages\IPython\core\pylabtools.py:151: UserWarning: Glyph 2979 (\N{TAMIL LETTER NNA}) missing from current font.
#   fig.canvas.print_figure(bytes_io, **kw)
# C:\Users\kaleeshwaran m\anaconda3\lib\site-packages\IPython\core\pylabtools.py:151: UserWarning: Glyph 2980 (\N{TAMIL LETTER TA}) missing from current font.
#   fig.canvas.print_figure(bytes_io, **kw)
# C:\Users\kaleeshwaran m\anaconda3\lib\site-packages\IPython\core\pylabtools.py:151: UserWarning: Glyph 3019 (\N{TAMIL VOWEL SIGN OO}) missing from current font.
#   fig.canvas.print_figure(bytes_io, **kw)
# C:\Users\kaleeshwaran m\anaconda3\lib\site-packages\IPython\core\pylabtools.py:151: UserWarning: Glyph 3016 (\N{TAMIL VOWEL SIGN AI}) missing from current font.
#   fig.canvas.print_figure(bytes_io, **kw)
# C:\Users\kaleeshwaran m\anaconda3\lib\site-packages\IPython\core\pylabtools.py:151: UserWarning: Glyph 2984 (\N{TAMIL LETTER NA}) missing from current font.
#   fig.canvas.print_figure(bytes_io, **kw)
# C:\Users\kaleeshwaran m\anaconda3\lib\site-packages\IPython\core\pylabtools.py:151: UserWarning: Glyph 3014 (\N{TAMIL VOWEL SIGN E}) missing from current font.
#   fig.canvas.print_figure(bytes_io, **kw)
# C:\Users\kaleeshwaran m\anaconda3\lib\site-packages\IPython\core\pylabtools.py:151: UserWarning: Glyph 2991 (\N{TAMIL LETTER YA}) missing from current font.
#   fig.canvas.print_figure(bytes_io, **kw)
# C:\Users\kaleeshwaran m\anaconda3\lib\site-packages\IPython\core\pylabtools.py:151: UserWarning: Glyph 2992 (\N{TAMIL LETTER RA}) missing from current font.
#   fig.canvas.print_figure(bytes_io, **kw)
# C:\Users\kaleeshwaran m\anaconda3\lib\site-packages\IPython\core\pylabtools.py:151: UserWarning: Glyph 3000 (\N{TAMIL LETTER SA}) missing from current font.
#   fig.canvas.print_figure(bytes_io, **kw)
# C:\Users\kaleeshwaran m\anaconda3\lib\site-packages\IPython\core\pylabtools.py:151: UserWarning: Glyph 2949 (\N{TAMIL LETTER A}) missing from current font.
#   fig.canvas.print_figure(bytes_io, **kw)
# C:\Users\kaleeshwaran m\anaconda3\lib\site-packages\IPython\core\pylabtools.py:151: UserWarning: Glyph 2994 (\N{TAMIL LETTER LA}) missing from current font.
#   fig.canvas.print_figure(bytes_io, **kw)

# %% [markdown]
# Worst performing videos

# %%
ax = sns.barplot(x = 'title', y = 'viewCount', data = video_df.sort_values('viewCount', ascending=True)[0:9])
plot = ax.set_xticklabels(ax.get_xticklabels(), rotation=90)
ax.yaxis.set_major_formatter(ticker.FuncFormatter(lambda x, pos:'{:,.0f}'.format(x/1000) + 'K'))

# %% [markdown]
# View distribution per video

# %%
sns.violinplot(x='channelTitle',y='viewCount',data=video_df)
# Out:
# <AxesSubplot:xlabel='channelTitle', ylabel='viewCount'>

# %%
#Views vs. likes and comments

# %%
fig, ax = plt.subplots(1,2)
sns.scatterplot(data = video_df, x = 'commentCount', y = 'viewCount', ax = ax[0])
sns.scatterplot(data = video_df, x = 'likeCount', y = 'viewCount', ax = ax[1])
# Out:
# <AxesSubplot:xlabel='likeCount', ylabel='viewCount'>

# %%
#Video duration

# %%
sns.histplot(data = video_df, x = 'durationSecs', bins=40)
# Out:
# <AxesSubplot:xlabel='durationSecs', ylabel='Count'>
